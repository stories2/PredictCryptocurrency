# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
dataFrame = pd.read_csv("Data/BTC_USD.csv")

# %%
dataFrame['y'] = dataFrame['y'] #np.log()
dataFrame.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2010.7.18 0:00</td>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2010.7.19 0:00</td>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2010.7.20 0:00</td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2010.7.21 0:00</td>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2010.7.22 0:00</td>
#       <td>0.05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model = Prophet()
model.fit(dataFrame)

# %%
future = model.make_future_dataframe(periods=365)
future.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3075</th>
#       <td>2018-12-18 19:49:00</td>
#     </tr>
#     <tr>
#       <th>3076</th>
#       <td>2018-12-19 19:49:00</td>
#     </tr>
#     <tr>
#       <th>3077</th>
#       <td>2018-12-20 19:49:00</td>
#     </tr>
#     <tr>
#       <th>3078</th>
#       <td>2018-12-21 19:49:00</td>
#     </tr>
#     <tr>
#       <th>3079</th>
#       <td>2018-12-22 19:49:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>yhat</th>
#       <th>yhat_lower</th>
#       <th>yhat_upper</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3075</th>
#       <td>2018-12-18 19:49:00</td>
#       <td>11991.219373</td>
#       <td>10544.084178</td>
#       <td>13453.998784</td>
#     </tr>
#     <tr>
#       <th>3076</th>
#       <td>2018-12-19 19:49:00</td>
#       <td>11947.242726</td>
#       <td>10526.762465</td>
#       <td>13354.363853</td>
#     </tr>
#     <tr>
#       <th>3077</th>
#       <td>2018-12-20 19:49:00</td>
#       <td>11902.943914</td>
#       <td>10527.890405</td>
#       <td>13282.290484</td>
#     </tr>
#     <tr>
#       <th>3078</th>
#       <td>2018-12-21 19:49:00</td>
#       <td>11838.405776</td>
#       <td>10367.925134</td>
#       <td>13165.440386</td>
#     </tr>
#     <tr>
#       <th>3079</th>
#       <td>2018-12-22 19:49:00</td>
#       <td>11763.058708</td>
#       <td>10322.769332</td>
#       <td>13049.003811</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.plot(forecast)

# %%
model.plot_components(forecast)
